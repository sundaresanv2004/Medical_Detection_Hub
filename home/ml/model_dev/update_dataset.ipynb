# %%
import tensorflow as tf
import pandas as pd
import os
from glob import glob

# %%
df = pd.read_csv("Skin_Cancer_data/HAM10000_metadata.csv")
print(df.shape)
df.head()
# Out:
# (10015, 7)
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lesion_id     10015 non-null  object
#  1   image_id      10015 non-null  object
#  2   dx            10015 non-null  object
#  3   dx_type       10015 non-null  object
#  4   age           9958 non-null   float64
#  5   sex           10015 non-null  object
#  6   localization  10015 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 547.8+ KB
# None

# %%
image_path = {os.path.splitext(os.path.basename(x))[0]: x for x in glob(os.path.join('Skin_Cancer_data/', '*', '*.jpg'))}

# %%
print(image_path)
# Out:
# {'ISIC_0026784': 'Skin_Cancer_data/HAM10000_images_part_1/ISIC_0026784.jpg', 'ISIC_0028971': 'Skin_Cancer_data/HAM10000_images_part_1/ISIC_0028971.jpg', 'ISIC_0026948': 'Skin_Cancer_data/HAM10000_images_part_1/ISIC_0026948.jpg', 'ISIC_0026790': 'Skin_Cancer_data/HAM10000_images_part_1/ISIC_0026790.jpg', 'ISIC_0028965': 'Skin_Cancer_data/HAM10000_images_part_1/ISIC_0028965.jpg', 'ISIC_0025299': 'Skin_Cancer_data/HAM10000_images_part_1/ISIC_0025299.jpg', 'ISIC_0024839': 'Skin_Cancer_data/HAM10000_images_part_1/ISIC_0024839.jpg', 'ISIC_0024811': 'Skin_Cancer_data/HAM10000_images_part_1/ISIC_0024811.jpg', 'ISIC_0026960': 'Skin_Cancer_data/HAM10000_images_part_1/ISIC_0026960.jpg', 'ISIC_0028795': 'Skin_Cancer_data/HAM10000_images_part_1/ISIC_0028795.jpg', 'ISIC_0026974': 'Skin_Cancer_data/HAM10000_images_part_1/ISIC_0026974.jpg', 'ISIC_0028781': 'Skin_Cancer_data/HAM10000_images_part_1/ISIC_0028781.jpg', 'ISIC_0028959': 'Skin_Cancer_data/HAM10000_images_part_1/ISIC_0028959.jpg', 'ISIC_002
# ...

# %%
df['path'] = df['image_id'].map(image_path.get)

# %%
df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                                 path
# 0  Skin_Cancer_data/HAM10000_images_part_1/ISIC_0...
# 1  Skin_Cancer_data/HAM10000_images_part_1/ISIC_0...
# 2  Skin_Cancer_data/HAM10000_images_part_1/ISIC_0...
# 3  Skin_Cancer_data/HAM10000_images_part_1/ISIC_0...
# 4  Skin_Cancer_data/HAM10000_images_part_2/ISIC_0...

# %%
classes = df['dx'].unique()
print(classes)
# Out:
# ['bkl' 'nv' 'df' 'mel' 'vasc' 'bcc' 'akiec']

# %%
for i in classes:
    print(i, ": ", len(df[df.dx == i]))
# Out:
# bkl :  1099
# nv :  6705
# df :  115
# mel :  1113
# vasc :  142
# bcc :  514
# akiec :  327

# %%
df.to_csv("Skin_Cancer_data/HAM10000_metadata_updated.csv", index=False)
